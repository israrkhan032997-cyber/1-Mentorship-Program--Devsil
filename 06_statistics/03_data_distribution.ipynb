# %% [markdown]
# # DATA DISTRIBUTION

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
# load the data from seaborn
df = sns.load_dataset('tips')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# draw a histoplot curve on it
plt.figure(figsize=(8, 6))
sns.histplot(data=df, x='total_bill', kde=True)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
# draw a histoplot curve on it
plt.figure(figsize=(8, 6))
sns.histplot(data=df, x='tip', kde=True)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
# draw a histoplot curve on it
plt.figure(figsize=(8, 6))
sns.histplot(data=df, x='day', kde=True)
# Out:
# <Axes: xlabel='day', ylabel='Count'>

# %%
# draw a histoplot curve on it
plt.figure(figsize=(8, 6))
sns.histplot(data=df, x='size', kde=True)
# Out:
# <Axes: xlabel='size', ylabel='Count'>

# %%
# load titanic data
df_01 = sns.load_dataset('titanic')
df_01.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.histplot(data= df_01, x='fare',kde=True)
# Out:
# <Axes: xlabel='fare', ylabel='Count'>

# %%
sns.histplot(data= df_01, x='fare',kde=True, bins=300)
# Out:
# <Axes: xlabel='fare', ylabel='Count'>

# %%
sns.histplot(data= df_01, x='fare',kde=True, bins=50, hue='class')
# Out:
# <Axes: xlabel='fare', ylabel='Count'>

# %%
sns.histplot(data= df_01, x='age',kde=True, bins=50, hue='class')
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.histplot(data= df_01, x='age',kde=True, bins=50, hue='who')
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.boxplot(data= df_01, x='age', hue='who')
# Out:
# <Axes: xlabel='age'>

# %%
sns.boxplot(data= df_01, x='age')
# Out:
# <Axes: xlabel='age'>

# %% [markdown]
# # DISTRIBUTION

# %%
# UNIFORM DISTRIBUTION PLOT
plt.subplot(3, 1, 2)
plt.hist(uniform_data, bins=30, color='skyblue', alpha=0.7)
plt.title('uniform distribution')
plt.xlabel('value')
plt.ylabel('Frequency')


# UNIFORM DISTRIBUTION PLOT
plt.subplot(3, 1, 2)
plt.hist(uniform_data, bins=30, color='lightgreen', alpha=0.7)
plt.title('uniform distribution')
plt.xlabel('value')
plt.ylabel('Frequency')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 3
#       1 # UNIFORM DISTRIBUTION PLOT
#       2 plt.subplot(3, 1, 2)
# ----> 3 plt.hist(uniform_data, bins=30, color='skyblue', alpha=0.7)
#       4 plt.title('uniform distribution')
#       5 plt.xlabel('value')
#
# NameError: name 'uniform_data' is not defined

# %% [markdown]
# # ASSIGHNMENT: why normal distribution is important in data science

# %% [markdown]
# -- how to normalize the data?

# %% [markdown]
# # kurtosis & skewness

# %%
from scipy import stats

# %%
df_01.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# find kurtosis of age
stats.kurtosis(df_01['age'], fisher=False)
# Out:
# np.float64(nan)

# %%
# find kurtosis of fare
stats.kurtosis(df_01['fare'], fisher=False)
# Out:
# np.float64(36.20428925264474)

# %%
stats.skew(df_01['fare'])
# Out:
# np.float64(4.7792532923723545)

# %%
sns.histplot(df_01, x = 'fare', kde=True)
# Out:
# <Axes: xlabel='fare', ylabel='Count'>

# %%
import numpy as np
from scipy.stats import skew, kurtosis

# Generating example data
np.random.seed(0)
data = np.random.normal(0, 1, 1000)  # Normal distribution

#calculating skewness and kurtosis
data_skewness = skew(data)
data_kurtosis = kurtosis(data, fisher=True)  # fisher=True 'gives the excess kurtosis'

# Displaying the results
print(f'skewness of the dataset: {data_skewness}')
print(f'kurtosis of the dataset: {data_kurtosis}')
# Out:
# skewness of the dataset: 0.03385895323565712
# kurtosis of the dataset: -0.0467663244783294

# %%
sns.histplot(data, kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
# find kurtosis of age in third class
df_third = df_01[df_01['class'] == 'Third']
stats.kurtosis(df_third['fare'],fisher=False)
# Out:
# np.float64(11.152944142950977)

# %%
stats.skew(df_third['fare'])
# Out:
# np.float64(2.7277063280299805)

# %%
sns.histplot(data = df_third, x = 'fare', kde=True, hue='class')
# Out:
# <Axes: xlabel='fare', ylabel='Count'>

# %% [markdown]
# # how to test the normal distribution of the data
#
# # H0: data is normally distributed
# # H1: data is not normally distributed
#
# # shpiro wilk
# # D'agostino's k^2 test

# %%
# shapiro wilk test to test the normality of the data
stats.shapiro(data)
print(f'shapiro-wilk test statistic: {stats.shapiro(data)[0]}')
print(f'shapiro-wilk test p-values: {stats.shapiro(data)[1]}')
# Out:
# shapiro-wilk test statistic: 0.9985554728235057
# shapiro-wilk test p-values: 0.5912267898687746
