# %% [markdown]
# # SPREAD OF DATA | DISPERSION | VARIABILITY

# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
# LETS FIND THE RANGE OF A DATA

df = np.array([10, 20, 30, 40, 50])

np.ptp(df)
# Out:
# np.int64(40)

# %% [markdown]
# # IQR----> (inter quartile range)

# %%
import matplotlib.pyplot as plt

# %%
# generating a dataset with potential outliers
np.random.seed(0)
data = np.random.normal(100, 20, 200)
data = np.append(data, [300, 5]) # adding a potential outliers

# calculating IQR
Q1 = np.percentile(data, 25)
Q2 = np.percentile(data, 50)
Q3 = np.percentile(data, 75)
Q4 = np.percentile(data,100)
IQR = Q3 - Q1
