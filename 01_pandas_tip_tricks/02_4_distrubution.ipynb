# %%
#FOUR DIMENSION FOR EDA

# 1-composition
# 2-distribution
# 3-comparison
# 4-relationship


#import library
import pandas as pd

# %%
 df= pd.read_csv("./data/kishti.csv")

# %%
#load the data
df = pd.read_csv("./data_pakistan.csv")
df.head(10)


df.head()
# Out:
#   PROVINCE             DIVISION               DISTRICT         SUB DIVISION  \
# 0   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT  BAHAWALNAGAR TEHSIL
# 1   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT     CHISHTIAN TEHSIL
# 2   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT    FORT ABBAS TEHSIL
# 3   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT    HAROONABAD TEHSIL
# 4   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT   MINCHINABAD TEHSIL
#
#    AREA (sq.km)  ALL SEXES (RURAL)  MALE (RURAL)  FEMALE (RURAL)  \
# 0        1729.0             619550        316864          302644
# 1        1500.0             540342        273788          266500
# 2        2536.0             361240        182655          178541
# 3        1295.0             382115        192278          189808
# 4        1818.0             452723        231506          221178
#
#    TRANSGENDER (RURAL)  SEX RATIO (RURAL)  ...  POPULATION 1998 (RURAL)  \
# ...

# %%
df = pd.read_csv("../data_set/kishti.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 df = pd.read_csv("../data_set/kishti.csv")
#
# File c:\Users\choice laptops\.conda\envs\Practice\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
#COMPOSITION
df.shape
#print the numbers of rows and columns using f string
print(f"rows: {df.shape[0]},\ncolumns:{df.shape[1]}")
# Out:
# rows: 528,
# columns:21

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 528 entries, 0 to 527
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   PROVINCE                    528 non-null    object
#  1   DIVISION                    528 non-null    object
#  2   DISTRICT                    528 non-null    object
#  3   SUB DIVISION                528 non-null    object
#  4   AREA (sq.km)                528 non-null    float64
#  5   ALL SEXES (RURAL)           528 non-null    int64
#  6   MALE (RURAL)                528 non-null    int64
#  7   FEMALE (RURAL)              528 non-null    int64
#  8   TRANSGENDER (RURAL)         528 non-null    int64
#  9   SEX RATIO (RURAL)           528 non-null    float64
#  10  AVG HOUSEHOLD SIZE (RURAL)  528 non-null    float64
#  11  POPULATION 1998 (RURAL)     528 non-null    int64
#  12  ANNUAL GROWTH RATE (RURAL)  528 non-null    float64
# ...

# %%
df.dtypes
#prints only the boolean columns
#print(df.select_dtypes(include='bool').columns)
# Out:
# PROVINCE                       object
# DIVISION                       object
# DISTRICT                       object
# SUB DIVISION                   object
# AREA (sq.km)                  float64
# ALL SEXES (RURAL)               int64
# MALE (RURAL)                    int64
# FEMALE (RURAL)                  int64
# TRANSGENDER (RURAL)             int64
# SEX RATIO (RURAL)             float64
# AVG HOUSEHOLD SIZE (RURAL)    float64
# POPULATION 1998 (RURAL)         int64
# ANNUAL GROWTH RATE (RURAL)    float64
# ALL SEXES (URBAN)               int64
# MALE (URBAN)                    int64
# FEMALE (URBAN)                  int64
# TRANSGENDER (URBAN)             int64
# SEX RATIO (URBAN)             float64
# AVG HOUSEHOLD SIZE (URBAN)    float64
# POPULATION 1998 (URBAN)         int64
# ANNUAL GROWTH RATE (URBAN)    float64
# dtype: object

# %%
df.head()
df["DISTRICT"].value_counts()
# Out:
# DISTRICT
# NORTH WAZIRISTAN DISTRICT    9
# KHUZDAR DISTRICT             9
# KHAIRPUR DISTRICT            8
# LASBELA DISTRICT             8
# SOUTH WAZIRISTAN DISTRICT    8
#                             ..
# FR BANNU DISTRICT            1
# FR KOHAT DISTRICT            1
# FR D.I.KHAN DISTRICT         1
# FR LAKKI MARWAT DISTRICT     1
# FR PESHAWAR DISTRICT         1
# Name: count, Length: 131, dtype: int64

# %%
#FIND VALUES COUNT PERCENTAGE FOR COLUMS

df["DISTRICT"].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0          BAHAWALNAGAR DISTRICT
# 1          BAHAWALNAGAR DISTRICT
# 2          BAHAWALNAGAR DISTRICT
# 3          BAHAWALNAGAR DISTRICT
# 4          BAHAWALNAGAR DISTRICT
#                  ...
# 523    SOUTH WAZIRISTAN DISTRICT
# 524    SOUTH WAZIRISTAN DISTRICT
# 525    SOUTH WAZIRISTAN DISTRICT
# 526    SOUTH WAZIRISTAN DISTRICT
# 527    SOUTH WAZIRISTAN DISTRICT
# Name: DISTRICT, Length: 528, dtype: object>

# %%
#TOTAL NUMBER OF ROWS

len(df)
# Out:
# 528

# %%
df["DISTRICT"].value_counts() / len(df) * 100
# Out:
# DISTRICT
# NORTH WAZIRISTAN DISTRICT    1.704545
# KHUZDAR DISTRICT             1.704545
# KHAIRPUR DISTRICT            1.515152
# LASBELA DISTRICT             1.515152
# SOUTH WAZIRISTAN DISTRICT    1.515152
#                                ...
# FR BANNU DISTRICT            0.189394
# FR KOHAT DISTRICT            0.189394
# FR D.I.KHAN DISTRICT         0.189394
# FR LAKKI MARWAT DISTRICT     0.189394
# FR PESHAWAR DISTRICT         0.189394
# Name: count, Length: 131, dtype: float64

# %%
#ROUND THE PERCENTAGE TO 2 DECIMAL PLACES

round(df["DISTRICT"].value_counts() / len(df) * 100, 2)
# Out:
# DISTRICT
# NORTH WAZIRISTAN DISTRICT    1.70
# KHUZDAR DISTRICT             1.70
# KHAIRPUR DISTRICT            1.52
# LASBELA DISTRICT             1.52
# SOUTH WAZIRISTAN DISTRICT    1.52
#                              ...
# FR BANNU DISTRICT            0.19
# FR KOHAT DISTRICT            0.19
# FR D.I.KHAN DISTRICT         0.19
# FR LAKKI MARWAT DISTRICT     0.19
# FR PESHAWAR DISTRICT         0.19
# Name: count, Length: 131, dtype: float64

# %%
round(df["PROVINCE"].value_counts() / len(df) * 100, 2)
# Out:
# PROVINCE
# PUNJAB         27.08
# SINDH          25.95
# BALOCHISTAN    24.81
# KPK            13.45
# KPK/FATA        8.71
# Name: count, dtype: float64

# %%
#FIND THE VALUE COUNTS IN PERCENTAGE FOR CLASS WHERE

df_DISTRICT = df[df["DISTRICT"]=="ALL SEXES (RURAL)"]
df_DISTRICT["DIVISION"].value_counts() / len(df) * 100
# Out:
# Series([], Name: count, dtype: float64)

# %%
df.head
# Out:
# <bound method NDFrame.head of      Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare  \
# 0             0         0       3    male  22.0      1      0   7.2500
# 1             1         1       1  female  38.0      1      0  71.2833
# 2             2         1       3  female  26.0      0      0   7.9250
# 3             3         1       1  female  35.0      1      0  53.1000
# 4             4         0       3    male  35.0      0      0   8.0500
# ..          ...       ...     ...     ...   ...    ...    ...      ...
# 886         886         0       2    male  27.0      0      0  13.0000
# 887         887         1       1  female  19.0      0      0  30.0000
# 888         888         0       3  female   NaN      1      2  23.4500
# 889         889         1       1    male  26.0      0      0  30.0000
# 890         890         0       3    male  32.0      0      0   7.7500
#
#     embarked   class    who  adult_male deck  embark_town alive  alone
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   891 non-null    int64
#  1   survived     891 non-null    int64
#  2   pclass       891 non-null    int64
#  3   sex          891 non-null    object
#  4   age          714 non-null    float64
#  5   sibsp        891 non-null    int64
#  6   parch        891 non-null    int64
#  7   fare         891 non-null    float64
#  8   embarked     889 non-null    object
#  9   class        891 non-null    object
#  10  who          891 non-null    object
#  11  adult_male   891 non-null    bool
#  12  deck         203 non-null    object
#  13  embark_town  889 non-null    object
#  14  alive        891 non-null    object
#  15  alone        891 non-null    bool
# dtypes: bool(2), float64(2), int64(5), object(7)
# memory usage: 99.3+ KB

# %%
df_females = df[df["sex"]=="female"]
df_females["class"].value_counts() / len(df) * 100
# Out:
# class
# Third     16.161616
# First     10.549944
# Second     8.529742
# Name: count, dtype: float64

# %%
len(df)
# Out:
# 891

# %%
#group by class and find the percentage of each class for sex column
df.groupby(["sex","class"]).size() / len(df) * 100
#FOR ROUND OFF

round(df.groupby(["sex","class"]).size() / len(df) * 100 ,2)
# Out:
# sex     class
# female  First     10.55
#         Second     8.53
#         Third     16.16
# male    First     13.69
#         Second    12.12
#         Third     38.95
# dtype: float64

# %%
round(df.groupby(["sex","class","embarked","fare"]).size() / len(df) * 100 ,2)
# Out:
# sex     class  embarked  fare
# female  First  C         27.7208    0.11
#                          28.7125    0.11
#                          31.0000    0.11
#                          39.6000    0.11
#                          49.5000    0.11
#                                     ...
# male    Third  S         34.3750    0.11
#                          39.6875    0.56
#                          46.9000    0.45
#                          56.4958    0.79
#                          69.5500    0.45
# Length: 370, dtype: float64

# %% [markdown]
# #DISTRIBUTION

# %%
df["age"].describe()
df["sex"].describe()
# Out:
# count      891
# unique       2
# top       male
# freq       577
# Name: sex, dtype: object

# %%
df.describe()
# Out:
#        Unnamed: 0    survived      pclass         age       sibsp       parch  \
# count  891.000000  891.000000  891.000000  714.000000  891.000000  891.000000
# mean   445.000000    0.383838    2.308642   29.699118    0.523008    0.381594
# std    257.353842    0.486592    0.836071   14.526497    1.102743    0.806057
# min      0.000000    0.000000    1.000000    0.420000    0.000000    0.000000
# 25%    222.500000    0.000000    2.000000   20.125000    0.000000    0.000000
# 50%    445.000000    0.000000    3.000000   28.000000    0.000000    0.000000
# 75%    667.500000    1.000000    3.000000   38.000000    1.000000    0.000000
# max    890.000000    1.000000    3.000000   80.000000    8.000000    6.000000
#
#              fare
# count  891.000000
# mean    32.204208
# std     49.693429
# min      0.000000
# 25%      7.910400
# 50%     14.454200
# 75%     31.000000
# max    512.329200

# %%
df["age"].plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
df["fare"].plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
df["age"].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: age, dtype: float64

# %%
df["age"].skew()
# Out:
# np.float64(0.38910778230082704)

# %%
df["fare"].skew()
# Out:
# np.float64(4.787316519674893)

# %% [markdown]
# comparison

# %%
df.groupby("class")["survived"].mean()
# Out:
# class
# First     0.629630
# Second    0.472826
# Third     0.242363
# Name: survived, dtype: float64

# %%
df.groupby("who")["survived"].mean()
# Out:
# who
# child    0.590361
# man      0.163873
# woman    0.756458
# Name: survived, dtype: float64

# %%
df.groupby(["sex","who","class"])["survived"].mean()
# Out:
# sex     who    class
# female  child  First     0.666667
#                Second    1.000000
#                Third     0.533333
#         woman  First     0.978022
#                Second    0.909091
#                Third     0.491228
# male    child  First     1.000000
#                Second    1.000000
#                Third     0.321429
#         man    First     0.352941
#                Second    0.080808
#                Third     0.119122
# Name: survived, dtype: float64

# %%
df.groupby("who")["survived"].mean().plot(kind="bar")
# Out:
# <Axes: xlabel='who'>

# %% [markdown]
# RELATIONSHIP

# %%
#create a corriation matrix only on int and float data from df
df.plot(kind="scatter",x="age",y="fare")
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %%
#coriation matrix
df[["age","fare"]].corr()
# Out:
#            age      fare
# age   1.000000  0.096067
# fare  0.096067  1.000000

# %%
df.groupby("survived")[["age","fare"]].mean()
# Out:
#                 age       fare
# survived
# 0         30.626179  22.117887
# 1         28.343690  48.395408

# %%
df[["age","fare"]].corr().plot(kind="bar",)
# Out:
# <Axes: >
