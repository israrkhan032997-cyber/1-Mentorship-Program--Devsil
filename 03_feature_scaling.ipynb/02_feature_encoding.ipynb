# %% [markdown]
# ### FEATURE ENCODING

# %% [markdown]
# ### 1. One hot encoding

# %%
import pandas as pd

#sample data
data = {'color':['red','green','blue','red']}
df = pd.DataFrame(data)
print(df)

# one-hot encoding
encoded_data = pd.get_dummies(df, columns=['color'])
print(encoded_data)
# Out:
#    color
# 0    red
# 1  green
# 2   blue
# 3    red
#    color_blue  color_green  color_red
# 0       False        False       True
# 1       False         True      False
# 2        True        False      False
# 3       False        False       True

# %% [markdown]
# ### 2. lable encoding

# %%
from sklearn.preprocessing import LabelEncoder

import pandas as pd

#sample data
data = {'animal':['dog','cat','bird','cat']}
df = pd.DataFrame(data)
print(df)
# lable encoding\
label_encoder = LabelEncoder()
df['animal_encoded'] = label_encoder.fit_transform(df['animal'])
print(df)
print(encoded_data)

#FOR INFORMATION 
#this one give me output in alphabatical order.
# Out:
#   animal
# 0    dog
# 1    cat
# 2   bird
# 3    cat
#   animal  animal_encoded
# 0    dog               2
# 1    cat               1
# 2   bird               0
# 3    cat               1
#    color_blue  color_green  color_red
# 0       False        False       True
# 1       False         True      False
# 2        True        False      False
# 3       False        False       True

# %% [markdown]
# ### 3. ordinal encoding

# %%
from sklearn.preprocessing import OrdinalEncoder

#sample data
data = {'size':['small','medium','large','medium']}
df = pd.DataFrame(data)
print(df)
# ordinal encoding
ordinal_encoder = OrdinalEncoder(categories=[['small','medium','large']])
df['size_encoded'] = ordinal_encoder.fit_transform(df[['size']])


print(df)
# Out:
#      size
# 0   small
# 1  medium
# 2   large
# 3  medium
#      size  size_encoded
# 0   small           0.0
# 1  medium           1.0
# 2   large           2.0
# 3  medium           1.0
